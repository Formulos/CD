# %% [markdown]
# ___
# # Atividade: Variáveis qualitativas com a PNAD (ALUNOS)
# ___
#
# ## Aula 02
#
#
# **Link úteis:**
# 1.	Leitura prévia necessária: Magalhães e Lima (7ª. Edição): pág. 9 a 16 – destacando para variáveis qualitativas.
# 2.	10 Minutes to Pandas: http://pandas.pydados.org/pandas-docs/stable/10min.html
# 3.	Essential Basic Functionality: http://pandas.pydados.org/pandas-docs/stable/basics.html
# 4.  Estude a aula `Aula02 Análise Exploratoria Variáveis Qualitativas-ALUNOS.ipynb`, o qual contém uma introdução ao Jupyter Notebook. A publicação dessa aula tem como objetivo auxiliá-lo, caso queira, no desenvolvimento dos seus próximos programas, como esta atividade.
#
# **Hoje:**
# 1.	Analisar variáveis qualitativas de forma uni e bivariadas utilizando tabelas de frequências e gráficos de barras e de pizza (ou setor).
# 2.  Trabalhar com a base de dados da PNAD 2013 - Pesquisa Nacional por Amostra de Domicílios
#
# **Próxima aula:**
# 1.	Leitura prévia necessária: Magalhães e Lima (7ª. Edição): pág. 9 a 17 – destacando para variáveis quantitativas; pág. 106 e 107 (Definição 4.1 e Exemplo 4.1).
#
# ___

# %% [markdown]
# ___
# ## <font color='blue'>PNAD 2013 – PESQUISA NACIONAL POR AMOSTRA DE DOMICÍLIOS</font>
#
# **Base de dados reduzida: ** `pes2013A.txt` (75 MB)
# [Acesse a base de dados aqui: https://dl.dropboxusercontent.com/u/65763596/Aula02/pes2013A.txt]
#
# **Dicionário das variáveis: ** `Dicionário de variáveis de pessoas - PNAD 2013.xlsx`
# [Acesse dicionário aqui: https://dl.dropboxusercontent.com/u/65763596/Aula02/Dicion%C3%A1rio%20de%20vari%C3%A1veis%20de%20pessoas%20-%20PNAD%202013.xls]
#
#
# Muitos especialistas na área de negócios dizem que empresários mais bem sucedidos são aqueles que fazem um planejamento antes de começar seu próprio negócio. Nessa visão, imagine que o Sr. Gold tenha como grande objetivo abrir uma nova faculdade e para isso deseja estudar o perfil do estudante que cursa ensino médio ou pré-vestibular e do que cursa ensino superior.
#
# Assuma que as variáveis de interesse a respeito dos estudantes sejam relativamente as mesmas de 2013 até o momento atual. Nesse caso, seja criativo para ajudar o Sr. Gold que deseja abrir seu negócio, mas não tem certeza sobre quais variáveis o interessam.
#
# Vocês podem ajudá-lo?!
#
# As variáveis a seguir devem fazer parte da sua análise:
#
# * V0302: sexo
# * V0404: cor ou raça
# * V6002: rede de ensino
# * V4802: nível de ensino e grupos de séries do ensino fundamental que frequentavam (todos os estudantes)
#
# ** Crie uma variável com região do indivíduo amostrado considerando a variável `estado` que define o estado e também trabalhe com essa nova variável em suas análises. **
#
# ** Escolha mais pelo menos DUAS variáveis qualitativas para completar sua análise!! **
#
# Faça uma análise exploratória apenas com as variáveis qualitativas com foco no objetivo do Sr. Gold.
#
# Sua análise deve conter pelo menos uma das seguintes visualizações:
#
# 1. Gráfico de colunas (bar) e setor (pie) com as frequências relativas cadas categorias das variáveis qualitativas.
# 2. Tabela cruzada entre pares de variaveis qualitativas. Montar o gráfico de colunas. Repetir o processo habilitando a opção "stacked=True".
#
#
# ___
#
#
# <font color='red'>
# Crie um repositório chamado CD em seu Github
# </font>
#
#
# Neste repositório, salve seu trabalho numa pasta chamada aula2
#
# Por exemplo, se seu login for *pikachu* o projeto vai estar na pasta:
#
# https://github.com/<font color=red>pikachu/CD/aula2</font>
#
#
#
# ## <font color='red'>Terça-feira (dia 16/08), no horário de atendimento da sua turma, deverá apresentar aos NINJAS!!</font>
# ___

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import os
import math
import numpy

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Paulo\Documents\GitHub\CD\Aula 2

# %%
dados = pd.read_table("pes2013A.txt", sep=" ")

# %%
print('acabou de ler')

"""
V4750
V8005 = idade
"""
# Out:
# acabou de ler
# '\nV4750\nV8005 = idade\n'

# %%
dados.sexo = dados.V0302.astype('category')
dados.cor = dados.V0404.astype('category')
dados.rede_ensino = dados.V6002.astype('category')
dados.rede_ensino_grupos = dados.V4802.astype('category')
dados.estado = dados.UF.astype('category')
dados.idade = dados.V8005.astype('float')
dados.renda = dados.V4750.astype('float') # Rendimento mensal familiar per capita

# %%
dados["regiao"] = dados.UF

dados.regiao[(dados.UF == 11 )| (dados.UF == 12 )| (dados.UF == 13 )| (dados.UF == 14 )| (dados.UF == 15 )| (dados.UF == 16 )| (dados.UF == 17)] = 'Norte'
dados.regiao[(dados.UF == 21 )| (dados.UF == 22 )| (dados.UF == 23 )| (dados.UF == 24 )| (dados.UF == 25 )| (dados.UF == 26 )| (dados.UF == 27 )| (dados.UF == 28 )| (dados.UF == 29)] = 'Nordeste'
dados.regiao[(dados.UF == 31 )| (dados.UF == 32 )| (dados.UF == 33 )| (dados.UF == 35)] = 'Sudeste'
dados.regiao[(dados.UF == 41 )| (dados.UF == 42 )| (dados.UF == 43)] = 'Sul'
dados.regiao[(dados.UF == 50 )| (dados.UF == 51 )| (dados.UF == 52 )| (dados.UF == 53)] = 'Centro Oeste'
# Out:
# C:\Users\Paulo\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\Paulo\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Paulo\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Paulo\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Paulo\Anaconda3\lib\site-packages\ipykernel\__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ct=pd.crosstab(dados.estado,dados.cor,margins=True,rownames=['Estado'], colnames=['cor'])


ct.index = ['Rondônia',
'Acre',
'Amazonas',
'Roraima',
'Pará',
'Amapá',
'Tocantins',
'Maranhão',
'Piauí',
'Ceará',
'Rio Grande do Norte',
'Paraíba',
'Pernambuco',
'Alagoas',
'Sergipe',
'Bahia',
'Minas Gerais',
'Espírito Santo',
'Rio de Janeiro',
'São Paulo',
'Paraná',
'Santa Catarina',
'Rio Grande do Sul',
'Mato Grosso do Sul',
'Mato Grosso',
'Goiás',
'Distrito Federal',
'All']


ct.columns = ['Branca',
'Preta',
'Amarela',
'Parda',
'Indígena',
'Sem declaração',
'All']

ct2=pd.crosstab(dados.estado,dados.sexo,margins=True,rownames=['Estado'], colnames=['cor'])


ct
# Out:
#                      Branca   Preta  Amarela  Parda  Indígena  Sem declaração  \
# Rondônia                 12    2500      482     17      4109               0
# Acre                    178     992      310     15      2980               0
# Amazonas                416    2833      514     51      9209               0
# Roraima                 115     618      289      3      1742               0
# Pará                    173    4817     2003     63     15399               0
# Amapá                     9     714      293      7      1867               0
# Tocantins                 9    1570      485     24      4369               0
# Maranhão                 36    1833     1133     35      6227               6
# Piauí                     5    1402      357     10      3818               0
# Ceará                    55    5759      757     38     12513               0
# Rio Grande do Norte       3    2024      286     14      2741               0
# Paraíba                  58    2175      342     18      3594               0
# Pernambuco              102    6955     1395     31     12078               0
# Alagoas                  19    1441      433     14      3554               0
# Sergipe                  15    1672      489     27      3886               0
# Bahia                   105    5395     5564     93     16090               0
# Minas Gerais             70   13941     3140     63     15923               0
# Espírito Santo           11    2643      638     14      3431               0
# Rio de Janeiro           30   12398     3456     58      9781               0
# São Paulo                49   24881     2548    412     11641               0
# Paraná                   29   13089      580    205      5142               0
# Santa Catarina           20    8353      274     15      1220               0
# Rio Grande do Sul        66   21921     1785     51      3366               0
# Mato Grosso do Sul       43    2921      344     51      2968               0
# Mato Grosso              10    2404      617     28      4089               0
# Goiás                    18    5841      901     61      7870               0
# Distrito Federal         32    4126      715     53      4435               0
# All                    1688  155218    30130   1471    174042               6
#
#                         All
# Rondônia               7120
# Acre                   4475
# Amazonas              13023
# Roraima                2767
# Pará                  22455
# Amapá                  2890
# Tocantins              6457
# Maranhão               9270
# Piauí                  5592
# Ceará                 19122
# Rio Grande do Norte    5068
# Paraíba                6187
# Pernambuco            20561
# Alagoas                5461
# Sergipe                6089
# Bahia                 27247
# Minas Gerais          33137
# Espírito Santo         6737
# Rio de Janeiro        25723
# São Paulo             39531
# Paraná                19045
# Santa Catarina         9882
# Rio Grande do Sul     27189
# Mato Grosso do Sul     6327
# Mato Grosso            7148
# Goiás                 14691
# Distrito Federal       9361
# All                  362555

# %%
ct2=pd.crosstab(dados.estado,dados.sexo,margins=True,rownames=['Estado'], colnames=['cor'])
ct2.index = ct.index

ct2.columns =['Masculino',
'Feminino',
'All'
]


ct2
# Out:
#                      Masculino  Feminino     All
# Rondônia                  3609      3511    7120
# Acre                      2226      2249    4475
# Amazonas                  6538      6485   13023
# Roraima                   1395      1372    2767
# Pará                     11110     11345   22455
# Amapá                     1445      1445    2890
# Tocantins                 3169      3288    6457
# Maranhão                  4591      4679    9270
# Piauí                     2720      2872    5592
# Ceará                     9217      9905   19122
# Rio Grande do Norte       2497      2571    5068
# Paraíba                   2942      3245    6187
# Pernambuco                9682     10879   20561
# Alagoas                   2593      2868    5461
# Sergipe                   3012      3077    6089
# Bahia                    13109     14138   27247
# Minas Gerais             16102     17035   33137
# Espírito Santo            3300      3437    6737
# Rio de Janeiro           12048     13675   25723
# São Paulo                19156     20375   39531
# Paraná                    9291      9754   19045
# Santa Catarina            4831      5051    9882
# Rio Grande do Sul        13088     14101   27189
# Mato Grosso do Sul        3129      3198    6327
# Mato Grosso               3573      3575    7148
# Goiás                     7342      7349   14691
# Distrito Federal          4387      4974    9361
# All                     176102    186453  362555

# %%
ct3=pd.crosstab(dados.estado,dados.rede_ensino,margins=True,rownames=['Estado'], colnames=['cor'])

ct3.index = ct.index
ct3.columns = ['Pública',
'Privada',
'All',
]

ct3
# Out:
#                      Pública  Privada     All
# Rondônia                1785      294    7120
# Acre                    1446      153    4475
# Amazonas                3764      838   13023
# Roraima                  769      134    2767
# Pará                    5947     1246   22455
# Amapá                    844      193    2890
# Tocantins               1750      297    6457
# Maranhão                2828      391    9270
# Piauí                   1499      310    5592
# Ceará                   4143     1476   19122
# Rio Grande do Norte     1123      346    5068
# Paraíba                 1331      497    6187
# Pernambuco              3855     1839   20561
# Alagoas                 1358      358    5461
# Sergipe                 1406      493    6089
# Bahia                   5852     2243   27247
# Minas Gerais            6817     2008   33137
# Espírito Santo          1421      377    6737
# Rio de Janeiro          4262     2259   25723
# São Paulo               7398     2663   39531
# Paraná                  3847     1177   19045
# Santa Catarina          1906      693    9882
# Rio Grande do Sul       5017     1793   27189
# Mato Grosso do Sul      1341      385    6327
# Mato Grosso             1631      417    7148
# Goiás                   2904     1091   14691
# Distrito Federal        1711     1218    9361
# All                    77955    25189  362555

# %%
ct4 = pd.crosstab(dados.estado,dados.rede_ensino_grupos,margins=True,rownames=['Estado'], colnames=['cor'])

ct4.index = ct.index

ct4.columns = ['Maternal, jardim de infância etc.',
'Classe de alfabetização',
'Alfabetização de adultos',
'1ª a 4ª séries do ensino fundamental regular em 8 anos ou de educação de jovens e adultos',
'5ª a 8ª séries do ensino fundamental regular em 8 anos ou de educação de jovens e adultos',
'1ª série do ensino fundamental regular em 9 anos',
'2ª a 5ª séries do ensino fundamental regular em 9 anos',
'6ª a 9ª séries do ensino fundamental regular em 9 anos',
'Educação de jovens e adultos não seriado do ensino fundamental',
'Ensino médio, inclusive pré-vestibular',
'Superior, inclusive mestrado ou doutorado',
'All'
]

ct4
# Out:
#                      Maternal, jardim de infância etc.  \
# Rondônia                                           101
# Acre                                                84
# Amazonas                                           271
# Roraima                                             47
# Pará                                               501
# Amapá                                               48
# Tocantins                                           93
# Maranhão                                           264
# Piauí                                              125
# Ceará                                              414
# Rio Grande do Norte                                 95
# Paraíba                                            143
# Pernambuco                                         340
# Alagoas                                            115
# Sergipe                                            149
# Bahia                                              537
# Minas Gerais                                       546
# Espírito Santo                                     101
# Rio de Janeiro                                     395
# São Paulo                                          614
# Paraná                                             230
# Santa Catarina                                     141
# Rio Grande do Sul                                  323
# Mato Grosso do Sul                                  88
# Mato Grosso                                        109
# Goiás                                              247
# Distrito Federal                                   172
# All                                               6293
#
#                      Classe de alfabetização  Alfabetização de adultos  \
# Rondônia                                  19                         5
# Acre                                      26                        11
# Amazonas                                  80                        11
# Roraima                                   16                         2
# Pará                                      51                        12
# Amapá                                     13                         6
# Tocantins                                 33                         2
# Maranhão                                  22                        33
# Piauí                                      8                        18
# Ceará                                     34                        37
# Rio Grande do Norte                       14                        19
# Paraíba                                   15                        16
# Pernambuco                                79                        25
# Alagoas                                   19                         9
# Sergipe                                   39                         8
# Bahia                                    141                        62
# Minas Gerais                              29                        44
# Espírito Santo                            23                         4
# Rio de Janeiro                           167                        19
# São Paulo                                 63                        15
# Paraná                                    29                        23
# Santa Catarina                            11                         7
# Rio Grande do Sul                         28                        21
# Mato Grosso do Sul                        24                         5
# Mato Grosso                               33                         7
# Goiás                                     35                         8
# Distrito Federal                          22                         6
# All                                     1073                       435
#
#                      1ª a 4ª séries do ensino fundamental regular em 8 anos ou de educação de jovens e adult
# Espírito Santo                                             259    6737
# Rio de Janeiro                                             842   25723
# São Paulo                                                 1488   39531
# Paraná                                                     794   19045
# Santa Catarina                                             484    9882
# Rio Grande do Sul                                         1122   27189
# Mato Grosso do Sul                                         292    6327
# Mato Grosso                                                320    7148
# Goiás                                                      623   14691
# Distrito Federal                                           674    9361
# All                                                      13644  362555

# %%
ct3 = ct3.iloc[0:-1,]


plot = ct3.plot(kind='bar', stacked=True,title='Rede de ensino')

# %%
dados.idade.describe()
# Out:
# count    362555.000000
# mean         33.049813
# std          20.870874
# min           0.000000
# 25%          16.000000
# 50%          31.000000
# 75%          48.000000
# max         109.000000
# Name: V8005, dtype: float64

# %%
#k = math.sqrt(362555)
k = 110/10
a = (109.0 - 0) / k
#print(a)

faixa =  numpy.arange(0,111,10)
#print(faixa)

variável_idade= pd.cut(dados.idade, faixa)

x = variável_idade.value_counts(True)*100

x.round(decimals=0)
# Out:
# (10, 20]      17
# (20, 30]      16
# (30, 40]      16
# (0, 10]       15
# (40, 50]      13
# (50, 60]      10
# (60, 70]       7
# (70, 80]       4
# (80, 90]       1
# (90, 100]      0
# (100, 110]     0
# dtype: float64

# %%
plot = dados.idade.plot.hist(bins=faixa)

# %%
dados.renda.describe()
# Out:
# count    3.618360e+05
# mean     4.899181e+10
# std      2.158512e+11
# min      0.000000e+00
# 25%      3.100000e+02
# 50%      6.000000e+02
# 75%      1.125000e+03
# max      1.000000e+12
# Name: V4750, dtype: float64

# %%
k = 110/10
a = (109.0 - 0) / k
#print(k)
dados.renda.sp = dados.renda[dados.estado=='São Paulo']


faixa_r =  numpy.arange(0,2500,100)
#print(len(faixa))

variável_renda= pd.cut(dados.renda, faixa_r)

x = variável_renda.value_counts(True)*100

x.round(decimals=0)
# Out:
# (200, 300]      10
# (300, 400]      10
# (400, 500]       9
# (600, 700]       8
# (100, 200]       8
# (500, 600]       7
# (700, 800]       5
# (800, 900]       4
# (0, 100]         4
# (900, 1000]      4
# (1000, 1100]     3
# (1100, 1200]     2
# (1300, 1400]     2
# (1200, 1300]     2
# (1400, 1500]     2
# (1600, 1700]     1
# (1900, 2000]     1
# (1500, 1600]     1
# (1700, 1800]     1
# (1800, 1900]     1
# (2100, 2200]     0
# (2200, 2300]     0
# (2000, 2100]     0
# (2300, 2400]     0
# dtype: float64

# %%
plot = dados.renda.plot.hist(bins=faixa_r)

# %%
idade_r = pd.DataFrame([dados.idade[dados.regiao == 'Sul'],dados.idade[dados.regiao == 'Centro Oeste'],dados.idade[dados.regiao == 'Sudeste'],dados.idade[dados.regiao == 'Norte'],dados.idade[dados.regiao == 'Nordeste']])

idade_r = idade_r.T

idade_r.head()
# Out:
#    V8005  V8005  V8005  V8005  V8005
# 1    NaN    NaN    NaN     42    NaN
# 2    NaN    NaN    NaN     64    NaN
# 3    NaN    NaN    NaN     13    NaN
# 4    NaN    NaN    NaN     23    NaN
# 5    NaN    NaN    NaN     19    NaN

# %%
idade_r.plot.box()
