# %% [markdown]
# ___
# # MINIPROJETO 1

# %% [markdown]
# ## <font color='red'>COLOQUE AQUI SEU NOME</font>
# ___

# %% [markdown]
# ## <font color='blue'>Quantidade de co2 produzido no mundo por capita</font>

# %% [markdown]
# ___
# ### Itens 1 a 3 - Resolução:

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
from scipy import stats

print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Paulo\Documents\GitHub\CD\Mini projeto 1

# %%
dados = pd.read_excel("WDI-world.xlsx")

# %%
co2_mtp = pd.DataFrame(dados.iloc[205,4:55])
#co2_mtp = co2_mtp.transpose()
co2_mtp.columns = ['CO2(metric tons)']

co2_mtp
# Out:
#      CO2(metric tons)
# 1960          3.09606
# 1961          3.06698
# 1962          3.13795
# 1963           3.2423
# 1964          3.35864
# 1965          3.43754
# 1966          3.53649
# 1967          3.57536
# 1968          3.68184
# 1969          3.82201
# 1970          4.01325
# 1971          4.07283
# 1972          4.15658
# 1973          4.29705
# 1974            4.222
# 1975          4.11854
# 1976          4.28298
# 1977          4.34941
# 1978          4.32556
# 1979          4.48731
# 1980          4.36306
# 1981          4.15609
# 1982          4.05049
# 1983          3.96379
# 1984          4.03644
# 1985          4.08617
# 1986          4.13724
# 1987          4.16577
# 1988          4.24071
# 1989          4.25799
# 1990          4.20228
# 1991          4.18573
# 1992          4.07911
# 1993          4.01381
# 1994          4.02518
# 1995          4.05095
# 1996          4.08853
# 1997          4.09696
# 1998          4.07125
# 1999          4.00854
# ...

# %%
teste = pd.DataFrame(dados.iloc[1382,0:58])
#co2_mtp = co2_mtp.transpose()
#teste.columns = ['farmeland']

teste
# Out:
#                             1382
# Country Name               World
# Country Code                 WLD
# Indicator Name  Urban population
# Indicator Code       SP.URB.TOTL
# 1960                 1.01463e+09
# 1961                 1.04407e+09
# 1962                 1.07581e+09
# 1963                 1.11047e+09
# 1964                 1.14599e+09
# 1965                 1.17679e+09
# 1966                 1.20816e+09
# 1967                 1.24005e+09
# 1968                 1.27213e+09
# 1969                 1.30625e+09
# 1970                 1.34035e+09
# 1971                 1.37536e+09
# 1972                 1.41139e+09
# 1973                 1.44821e+09
# 1974                 1.48732e+09
# 1975                 1.52442e+09
# 1976                 1.56177e+09
# 1977                 1.59971e+09
# 1978                 1.64179e+09
# 1979                 1.68795e+09
# 1980                 1.73521e+09
# 1981                  1.7845e+09
# 1982                  1.8338e+09
# ...

# %%
plot = teste.plot.hist(bins=10,label = 'CO2')
#plt.legend(loc='upper left')
plt.show()

# %%
faixa =  np.arange(3,5,0.2)

variável_idade= pd.cut(co2_mtp, faixa)
print(variável_idade.value_counts((True)*100))


plot = co2_mtp.plot.hist(bins=faixa,label = 'CO2')
plt.legend(loc='upper left')
plt.show()
# Out:
# (3, 3.2]       3
# (3.2, 3.4]     2
# (3.4, 3.6]     3
# (3.6, 3.8]     1
# (3.8, 4]       2
# (4, 4.2]      22
# (4.2, 4.4]    10
# (4.4, 4.6]     3
# (4.6, 4.8]     4
# dtype: int64

# %% [markdown]
# ___
# ### Itens 4 a 6 - Resolução:

# %% [markdown]
# É um caso (infeliz) de simetria negativa.

# %% [markdown]
# Ele pode seguir a distribuição de Poisson,pois esses elementos são idependentes e o tempo entre as ocorrencias são proporcionais.Tamebm seria possivel seguir a distribuição normal, pois a media e a mediana não são muito diferentes, como mostrado abaixo.

# %%
print(co2_mtp.mean())
print(co2_mtp.median())
# Out:
# CO2(metric tons)    4.071436
# dtype: float64
# CO2(metric tons)    4.096963
# dtype: float64

# %% [markdown]
# ___
# ### Itens 7 a 9 - Resolução:

# %% [markdown]
# ___
# ### Itens 10 e 11 - Resolução:
